# %%
import requests, bs4
import pandas as pd
from lxml import html
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote
import requests
import json
import pandas as pd

#API KEY
my_key = 'cbp8333o530rtbb44j50jce00r3occ8t'

# 샘플 url 변형해서 사용

endpoint=f"https://open.jejudatahub.net/api/proxy/5D5a577taba7tbb71at1b1bt9tatata9/{my_key}?startDate=201601&endDate=201902&number=99"

#api 호출
resp=requests.get(endpoint)
print(resp.status_code)
print(resp.text)

#joson 파일로 가져왔기때문에, json() 함수로 data에 넣어주기
data=resp.json()

resp

import pandas as pd
from pandas.io.json import json_normalize
dfdata=pd.json_normalize(data['data'])
dfdata
# Out:
# 200
# ...

# %%
dfdata.to_csv("carddata.csv")
