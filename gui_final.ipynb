# %%
from tkinter import *
import tkinter as tk
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

root = tk.Tk()
rt1= tk.Tk()
rt2= tk.Tk()
rt3= tk.Tk()
rt4= tk.Tk()

    

def openrt2():
    #rt2 디자인r=rt1)
    btn2=PhotoImage(file='bt3.png',master=rt2)
    bg2=PhotoImage(file='png2.png',master=rt2)
    bg_label2=Label(rt2,image=bg2)
    bg_label2.place(x=0,y=0)
    rt2.geometry('300x500+300+0')
    
    rt2_lst=Listbox(rt2,selectmode='single', height=4)
  
    for i in ['건입동', '구좌읍', '남원읍', '노형동','대륜동', '대정읍', '대천동', 
              '도두동', '동홍동', '봉개동', '삼도1동', '삼도2동', '삼양동', '서홍동', 
              '성산읍', '송산동', '아라동', '안덕면', '애월읍', '연동', '영천동', 
              '예래동', '오라동', '외도동', '용담1동', '용담2동', '우도면', '이도1동', 
              '이도2동', '이호동', '일도1동', '일도2동', '정방동', '조천읍', '중문동',
              '중앙동', '천지동', '추자면', '표선면', '한경면', '한림읍', '화북동', '효돈동']:
        
        rt2_lst.insert(END, i)
    
    rt2_lst.place(x=75,y=150)
    
    def getlst2():
        c=rt2_lst.curselection()
        d=rt2_lst.get(c)
        print('선택된 항목:',d)
        def openrt4():
            rt4.geometry('300x500+600+0')
            lb2=Label(rt4,width = 20, height = 5,text=d)
            lb2.pack()
            rt4.mainloop()
        openrt4()
    
    rt2_bt1=Button(rt2,width=150, height = 50,image=btn2,command=getlst2)
    rt2_bt1.place(x=70,y=250)
    
    
    scb=Scrollbar(rt2,width=20,orient='vertical')
    scb.config(command=rt2_lst.yview)
    scb.place(x=210,y=160)
    
    rt2_lst.config(yscrollcommand=scb.set)
    rt2.mainloop()
    
def openrt1():
    #rt1 디자인r=rt1)
    btn1=PhotoImage(file='bt3.png',master=rt1)
    bg1=PhotoImage(file='png3.png',master=rt1)
    bg_label1=Label(rt1,image=bg1)
    bg_label1.place(x=0,y=0)
    rt1.geometry('300x500+300+0')
    
    rt1_lst=Listbox(rt1,selectmode='single', height=0)
    rt1_lst.insert(0,'소매')
    rt1_lst.insert(1,'숙박')
    rt1_lst.insert(2,'식음료')
    rt1_lst.insert(3,'문화/레져')
    rt1_lst.place(x=75,y=150)
    
    def getlst1():
        a=rt1_lst.curselection()
        b=rt1_lst.get(a)
        print('선택된 항목:',b)
        def openrt3():
            rt3.geometry('300x500+600+0')
            lb1=Label(rt3,width = 20, height = 5,text=b)
            lb1.pack()
            rt3.mainloop()
        openrt3()
    
    rt1_bt1=Button(rt1,width=150, height = 50,image=btn1,command=getlst1)#,command=closert1
    rt1_bt1.place(x=70,y=250)
    rt1.mainloop()
    

def closert1():
    rt1.destroy()

def closert2():
    rt2.destroy()
    
    
root.geometry('300x500+0+0')
bg=PhotoImage(file='png1.png',master=root)
bg_label=Label(root,image=bg)
bg_label.place(x=0,y=0)

bt_bg1=PhotoImage(file='bt2.png',master=root)
bt1=Button(root,width=150, height=50, image=bt_bg1,command=openrt1)
bt1.place(x=132, y=140)

bt_bg2=PhotoImage(file='bt1.png',master=root)
bt2=Button(root,width=150, height=50, image=bt_bg2,command=openrt2)
bt2.place(x=132, y=215)

root.mainloop()
# Out:
# 선택된 항목: 소매

# %%
#10_20

import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='천지동']
o_card=p_card[p_card['업종']=='소매업']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2

x1 = float(o_card['사용금액'][161])
x2 = float(o_card['사용금액'][162])
x3 = float(o_card['사용금액'][163])
labels2 = '1020', '304050', '6070' 
pieSizes = [float(x1),float(x2),float(x3)]
#pieSizes = [0.854019423,0.007868807,0.131966623]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()


labels3 = '1020', '304050', '6070' 
pieSizes3 = [0.805509794,0.028647421,0.135282387]
my_colors3 = ['lightblue','lightsteelblue','silver']
explode3 = (0.1, 0.1, 0.1)  
ax3.pie(pieSizes3, colors=my_colors3, explode=explode3, labels=labels3, autopct='%1.1f%%', shadow=True, startangle=90) 
ax3.axis('equal')  
pie3 = FigureCanvasTkAgg(figure2, root)
pie3.get_tk_widget().pack()
plt.show()


root.mainloop()

# %%
'''import pandas as pd
import csv
udong=pd.read_csv('Udong20.csv')
udong
u_card=pd.read_excel('2020_card.xlsx')
u_card'''
# Out:
#      읍면동    업종        나이           사용금액
# 0    천지동  소매업      10_20   25378.404255
# 1    천지동  소매업   30_40_50  107001.145631
# 2    천지동  소매업      60_70  117757.980769
# 3    천지동   식음료     10_20  217050.249110
# 4    천지동   식음료  30_40_50  345722.933419
# ..   ...   ...       ...            ...
# 823  삼양동   식음료  30_40_50  489997.763636
# 824  삼양동   식음료     60_70  189618.220339
# 825  봉개동   소매업     10_20  112772.727273
# 826  봉개동   소매업  30_40_50  156881.578947
# 827  봉개동   소매업     60_70  118173.333333
#
# [828 rows x 4 columns]

# %%
'''
uu=(u_card['읍면동']=='송산동')
u_card[uu]'''
'''uu=(u_card['읍면동']=='일도1동')
u_card[uu]'''
# Out:
#       읍면동    업종        나이          사용금액
# 669  일도1동   소매업     10_20  6.392519e+05
# 670  일도1동   소매업  30_40_50  1.468744e+06
# 671  일도1동   소매업     60_70  1.347485e+06
# 672  일도1동   식음료     10_20  5.718029e+05
# 673  일도1동   식음료  30_40_50  7.993482e+05
# 674  일도1동   식음료     60_70  4.639359e+05
# 675  일도1동    숙박     10_20  4.395075e+05
# 676  일도1동    숙박  30_40_50  5.993605e+05
# 677  일도1동    숙박     60_70  3.110539e+05
# 678  일도1동  문화레저     10_20  1.870803e+06
# 679  일도1동  문화레저  30_40_50  2.283798e+06
# 680  일도1동  문화레저     60_70  1.815543e+06

# %%
#소매 1020
import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='송산동']
o_card=p_card[p_card['업종']=='소매업']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2

x1 = float(o_card['사용금액'][61])
x2 = float(o_card['사용금액'][62])
x3 = float(o_card['사용금액'][63])
labels2 = '1020', '304050', '6070' 
pieSizes = [float(x1),float(x2),float(x3)]
#pieSizes = [0.854019423,0.007868807,0.131966623]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()



root.mainloop()

# %%
#문화레저 1020
import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='일도 1동']
o_card=p_card[p_card['업종']=='문화레저']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2

x1 = float(o_card['사용금액'][678])
x2 = float(o_card['사용금액'][679])
x3 = float(o_card['사용금액'][680])
labels2 = '1020', '304050', '6070' 
pieSizes = [float(x1),float(x2),float(x3)]
#pieSizes = [0.854019423,0.007868807,0.131966623]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()



root.mainloop()

# %%
#숙박 1020
import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='예래동']
o_card=p_card[p_card['업종']=='숙박']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2

x1 = float(o_card['사용금액'][122])
x2 = float(o_card['사용금액'][123])
x3 = float(o_card['사용금액'][124])
labels2 = '1020', '304050', '6070' 
pieSizes = [float(x1),float(x2),float(x3)]
#pieSizes = [0.854019423,0.007868807,0.131966623]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()



root.mainloop()

# %%
#식음료 1020
import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='송산동']
o_card=p_card[p_card['업종']=='소매업']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')

global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2

x1 = float(o_card['사용금액'][63])
x2 = float(o_card['사용금액'][64])
x3 = float(o_card['사용금액'][65])
labels2 = '1020', '304050', '6070' 
pieSizes = [float(x1),float(x2),float(x3)]
#pieSizes = [0.854019423,0.007868807,0.131966623]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()



root.mainloop()

# %%
#노형동

import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='노형동']
o_card=p_card[p_card['업종']=='소매업']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2
'''
x1 = float(o_card['사용금액'][161])
x2 = float(o_card['사용금액'][162])
x3 = float(o_card['사용금액'][163])'''
labels2 = '음식', '숙박업', '소매업' 
#pieSizes = [float(x1),float(x2),float(x3)]
pieSizes = [0.854019423,0.007868807,0.131966623]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()


labels3 = '음식', '숙박업', '소매업' 
pieSizes3 = [0.805509794,0.028647421,0.135282387]
my_colors3 = ['lightblue','lightsteelblue','silver']
explode3 = (0.1, 0.1, 0.1)  
ax3.pie(pieSizes3, colors=my_colors3, explode=explode3, labels=labels3, autopct='%1.1f%%', shadow=True, startangle=90) 
ax3.axis('equal')  
pie3 = FigureCanvasTkAgg(figure2, root)
pie3.get_tk_widget().pack()
plt.show()


root.mainloop()

# %%
#송산동'

import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='송산동']
o_card=p_card[p_card['업종']=='소매업']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2

labels2 = '숙박', '소매업', '식음료' 

pieSizes = [0.032217711
,0.201548304
,0.732666291]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()


labels3 = '숙박', '소매업', '식음료' 
pieSizes3 = [0.066150043,
0.23618049,
0.609999876]
my_colors3 = ['lightblue','lightsteelblue','silver']
explode3 = (0.1, 0.1, 0.1)  
ax3.pie(pieSizes3, colors=my_colors3, explode=explode3, labels=labels3, autopct='%1.1f%%', shadow=True, startangle=90) 
ax3.axis('equal')  
pie3 = FigureCanvasTkAgg(figure2, root)
pie3.get_tk_widget().pack()
plt.show()


root.mainloop()

# %%
#애월읍
import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='애월읍']
o_card=p_card[p_card['업종']=='소매업']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2
'''
x1 = float(o_card['사용금액'][161])
x2 = float(o_card['사용금액'][162])
x3 = float(o_card['사용금액'][163])'''
labels2 = '숙박업', '식음료', '소매업' 
#pieSizes = [float(x1),float(x2),float(x3)]
pieSizes = [0.040099023,
0.852911383,
0.095089462]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()


labels3 = '숙박업', '식음료', '소매업' 
pieSizes3 = [0.108863734,
0.780265114,
0.10154485]
my_colors3 = ['lightblue','lightsteelblue','silver']
explode3 = (0.1, 0.1, 0.1)  
ax3.pie(pieSizes3, colors=my_colors3, explode=explode3, labels=labels3, autopct='%1.1f%%', shadow=True, startangle=90) 
ax3.axis('equal')  
pie3 = FigureCanvasTkAgg(figure2, root)
pie3.get_tk_widget().pack()
plt.show()


root.mainloop()

# %%
#연동'

import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='연동']
o_card=p_card[p_card['업종']=='소매업']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2
'''
x1 = float(o_card['사용금액'][161])
x2 = float(o_card['사용금액'][162])
x3 = float(o_card['사용금액'][163])'''
labels2 = '소매업', '숙박업', '식음료' 
#pieSizes = [float(x1),float(x2),float(x3)]
pieSizes = [0.096624846,
0.051824674,
0.821350618]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()


labels3 = '소매업', '숙박업', '식음료' 
pieSizes3 = [0.054004203,
0.18700358,
0.673334212]
my_colors3 = ['lightblue','lightsteelblue','silver']
explode3 = (0.1, 0.1, 0.1)  
ax3.pie(pieSizes3, colors=my_colors3, explode=explode3, labels=labels3, autopct='%1.1f%%', shadow=True, startangle=90) 
ax3.axis('equal')  
pie3 = FigureCanvasTkAgg(figure2, root)
pie3.get_tk_widget().pack()
plt.show()


root.mainloop()

# %%
#'이동2동',


import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='이동2동']
o_card=p_card[p_card['업종']=='소매업']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2
'''
x1 = float(o_card['사용금액'][161])
x2 = float(o_card['사용금액'][162])
x3 = float(o_card['사용금액'][163])'''
labels2 = '식음료', '소매업', '숙박업' 
#pieSizes = [float(x1),float(x2),float(x3)]
pieSizes = [0.862348857,
0.120387757,
0.007236592]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()


labels3 = '식음료', '소매업', '숙박업' 
pieSizes3 = [0.797928809,
0.144282214,
0.021633221]
my_colors3 = ['lightblue','lightsteelblue','silver']
explode3 = (0.1, 0.1, 0.1)  
ax3.pie(pieSizes3, colors=my_colors3, explode=explode3, labels=labels3, autopct='%1.1f%%', shadow=True, startangle=90) 
ax3.axis('equal')  
pie3 = FigureCanvasTkAgg(figure2, root)
pie3.get_tk_widget().pack()
plt.show()


root.mainloop()

# %%
#'정방동',

import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='정방동']
o_card=p_card[p_card['업종']=='소매업']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2

labels2 = '소매업','숙박업','식음료' 
#pieSizes = [float(x1),float(x2),float(x3)]
pieSizes = [0.236732625,
0.031230283,
0.696677101]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()


labels3 = '소매업','숙박업','식음료' 
pieSizes3 = [0.263144499,
0.063597495,
0.56913744]
my_colors3 = ['lightblue','lightsteelblue','silver']
explode3 = (0.1, 0.1, 0.1)  
ax3.pie(pieSizes3, colors=my_colors3, explode=explode3, labels=labels3, autopct='%1.1f%%', shadow=True, startangle=90) 
ax3.axis('equal')  
pie3 = FigureCanvasTkAgg(figure2, root)
pie3.get_tk_widget().pack()
plt.show()


root.mainloop()

# %%
#'중앙동'

import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='중앙동']
o_card=p_card[p_card['업종']=='소매업']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2
'''
x1 = float(o_card['사용금액'][161])
x2 = float(o_card['사용금액'][162])
x3 = float(o_card['사용금액'][163])'''
labels2 = '소매업', '숙박업', '식음료' 
#pieSizes = [float(x1),float(x2),float(x3)]
pieSizes = [0.236732625,
0.031230283,
0.696677101]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()


labels3 = '소매업', '숙박업', '식음료' 
pieSizes3 = [0.263144499,
0.063597495,
0.56913744]
my_colors3 = ['lightblue','lightsteelblue','silver']
explode3 = (0.1, 0.1, 0.1)  
ax3.pie(pieSizes3, colors=my_colors3, explode=explode3, labels=labels3, autopct='%1.1f%%', shadow=True, startangle=90) 
ax3.axis('equal')  
pie3 = FigureCanvasTkAgg(figure2, root)
pie3.get_tk_widget().pack()
plt.show()


root.mainloop()

# %%
#'천지동'

import tkinter as tk
from tkinter import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

df = pd.read_csv('Udong20.csv')
card=pd.read_excel('2020_card.xlsx')
p_card=card[card['읍면동']=='천지동']
o_card=p_card[p_card['업종']=='소매업']

root=Tk()
root.geometry('1000x700+0+0') #root 창 크기  

bg=PhotoImage(file='png4.png',master=root)
bg_label=Label(root,image=bg)# 배경 레이블 생성
bg_label.place(x=0,y=0)

#두번째 레이블 생성
bg3=PhotoImage(file='png5.png',master=root)
label2=Label(root,image=bg3)
label2.pack(side=LEFT,padx=51)

#확인 버튼 생성
cbt=Button(root,width=75,height=3,text='확인')
cbt.pack(side=BOTTOM,pady=10)

figure=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure1=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure2=plt.Figure(figsize=(11,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure3=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기
figure4=plt.Figure(figsize=(5.2,3), dpi=45) #Figure 객체 생성 및 그래프 크기

ax1= figure.add_subplot(1,1,1) #3-전체 행 , 1-그래프 보여줄 열 , 1-그래프를 보여줄 행 선택
ax2= figure1.add_subplot(1,1,1)
ax3= figure2.add_subplot(1,1,1)
ax4= figure3.add_subplot(1,1,1)
ax5= figure4.add_subplot(1,1,1)

line1=FigureCanvasTkAgg(figure,root) 
line1.get_tk_widget().pack(side=BOTTOM,pady=5)
line2=FigureCanvasTkAgg(figure1,root) 
line2.get_tk_widget().pack(side=BOTTOM,pady=5)
line3=FigureCanvasTkAgg(figure2,root) 
line3.get_tk_widget().pack(side=BOTTOM,pady=5)
line4=FigureCanvasTkAgg(figure3,root) 
line4.get_tk_widget().place(x=479,y=50)
line5=FigureCanvasTkAgg(figure4,root) 
line5.get_tk_widget().place(x=741,y=50)

#첫번째 레이블 생성
label1=Label(root,width=76,height=2,text='소매업에 추천드릴 지역은 oo 입니다. ')
label1.place(x=459,y=5)

df1=df['이용자수'].groupby(df['읍면동명']).sum() #보여줄 그래프
df1.plot(kind='line',ax=ax1, color='g',marker='o',fontsize='10') # 선 그래프 형태
ax1.set_title('Line graph')#그래프 제목

'''
df2=df['이용자수'].groupby(df['읍면동명']).sum()
df2.plot(kind='bar',ax=ax2, color='r',fontsize='10') # 막대 그래프 형태
ax2.set_title('Bar graph')
'''

df3=df['이용자수'].groupby(df['읍면동명']).sum()
df3.plot(kind='hist',ax=ax3, color='b',fontsize='10')
ax3.set_title('sum of local')

df4=df['이용자수'].groupby(df['읍면동명']).sum()
df4.plot(kind='hist',ax=ax4, color='g',fontsize='10')
ax4.set_title('sum of local')

df5=df['이용자수'].groupby(df['읍면동명']).sum()
df5.plot(kind='bar',ax=ax5, color='r',fontsize='10')
ax5.set_title('sum of local')
global x1
global x2
global x3
global y1
global y2
global y3
global pie3
global pie2
'''
x1 = float(o_card['사용금액'][161])
x2 = float(o_card['사용금액'][162])
x3 = float(o_card['사용금액'][163])'''
labels2 = '소매업', '숙박업', '식음료' 
#pieSizes = [float(x1),float(x2),float(x3)]
pieSizes = [0.217694429,
0.028718916,
0.722746249]
my_colors2 = ['lightblue','lightsteelblue','silver']
explode2 = (0.1, 0.1, 0.1)  
ax2.pie(pieSizes, colors=my_colors2, explode=explode2, labels=labels2, autopct='%1.1f%%', shadow=True, startangle=90) 
ax2.axis('equal')  
pie2 = FigureCanvasTkAgg(figure2, root)
pie2.get_tk_widget().pack()
plt.show()


labels3 = '소매업', '숙박업', '식음료'  
pieSizes3 = [0.247664882,
0.062226709,
0.593235035]
my_colors3 = ['lightblue','lightsteelblue','silver']
explode3 = (0.1, 0.1, 0.1)  
ax3.pie(pieSizes3, colors=my_colors3, explode=explode3, labels=labels3, autopct='%1.1f%%', shadow=True, startangle=90) 
ax3.axis('equal')  
pie3 = FigureCanvasTkAgg(figure2, root)
pie3.get_tk_widget().pack()
plt.show()


root.mainloop()
